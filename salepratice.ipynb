# %%
# setting up pyspark environment
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# !pip install pyspark
# !pip install -U -q PyDrive

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

import pyspark
import pyspark.sql  as pyspark_sql
import pyspark.sql.types as pyspark_types
import pyspark.sql.functions  as F
from pyspark import SparkContext, SparkConf

conf = SparkConf().set('spark ui port','4050')
sc = pyspark.SparkContext(conf=conf)
from pyspark.sql import SparkSession


# Create a SparkSession
spark = SparkSession.builder \
    .appName("Read CSV") \
    .getOrCreate()
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=68ef4caeefd971c776833b5d1055e03d7c3e9459728e763df42221b189091bdb
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
spark = SparkSession.builder \
    .appName("DecimalFormatExample") \
    .config("spark.sql.decimalOperations.allowPrecision", "true") \
    .config("spark.sql.decimalOperations.allowScale", "true") \
    .getOrCreate()

# %%
# Read csv file
df = spark.read.csv("/content/drive/MyDrive/salerecord.csv" ,header = True,inferSchema= True)
df.show()
# Out:
# +--------------------+------------+---------------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# |              Region|     Country|      Item Type|Sales Channel|Order Priority|Order Date| Order ID| Ship Date|Units Sold|Unit Price|Unit Cost|Total Revenue|Total Cost|Total Profit|
# +--------------------+------------+---------------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# |Australia and Oce...|       Palau|Office Supplies|       Online|             H|  3/6/2016|517073523| 3/26/2016|      2401|    651.21|   524.96|   1563555.21|1260428.96|   303126.25|
# |              Europe|      Poland|      Beverages|       Online|             L| 4/18/2010|380507028| 5/26/2010|      9340|     47.45|    31.79|     443183.0|  296918.6|    146264.4|
# |       North America|      Canada|         Cereal|       Online|             M|  1/8/2015|504055583| 1/31/2015|       103|     205.7|   117.11|      21187.1|  12062.33|     9124.77|
# |              Europe|     Belarus|         Snacks|       Online|             C| 1/19/2014|954955518| 2/27/2014|      1414|    152.58|    97.44|    215748.12| 137780.16|    77967.96|
# |Middle East and N...|        Oman|         Cereal|      Offline|             H| 4/26/2019|970755660|  6/2/2019|      7027|     205.7|   117.11|    1445453.9| 822931.97|   622521.93|
# |  Sub-Saharan Africa|Burkina Faso|Office Supplies|       Online|             C|  3/3/2012|309317338|  4/5/2012|      2729|    651.21|   524.96|   1777152.09|1432615.84|   344536.25|
# |              Europe|  Montenegro|  Personal Care|       Online|             H|11/24/2012|598814380|12/25/2012|      1337|     81.73|    56.67|    109273.01|  75767.79|    33505.22|
# |Middle East and N...|  Azerbaijan|      Cosmetics|      Offline|             M| 3/18/2011|387733113|  5/5/2011|      7699|     437.2|   263.33|    3366002.8|2027377.67|  1338625.13|
# |  Sub-Saharan Africa| South Sudan|        Clothes|      Offline|             C| 5/10/2014|994872367| 6/17/2014|      3696|    109.28|    35.84|    403898.88| 132464.64|   271434.24|
# |       North America|   Greenland|  Personal Care|       Online|             C| 5/25/2020|659343469| 6/14/2020|      3239|     81.73|    56.67|    264723.47| 183554.13|    81169.34|
# |              Europe|    Portugal|      Cosmetics|       Online|             M|11/12/2012|390570247|11/13/2012|      7270|     437.2|   263.33|    3178444.0| 1914409.1|   1264034.9|
# |  Sub-Saharan Africa|Sierra Leone|        Clothes|      Offline|             C| 7/25/2019|818289029| 7/27/2019|      8763|    109.28|    35.84|    957620.64| 314065.92|   643554.72|
# |              Europe|     Germany|  Personal Care|      Offline|             H|12/25/2010|842548644| 1/24/2011|      7722|     81.73|    56.67|    631119.06| 437605.74|   193513.32|
# |              Europe|  Montenegro|  Personal Care|      Offline|             L|  8/3/2012|783710420| 8/10/2012|      6184|     81.73|    56.67|    505418.32| 350447.28|   154971.04|
# |                Asia|  Bangladesh|         Cereal|      Offline|             L| 12/3/2013|132448184| 1/15/2014|      3216|     205.7|   117.11|     661531.2| 376625.76|   284905.44|
# |  Sub-Saharan Africa|  Mauritius |         Snacks|       Online|             M| 9/22/2016|699748265| 10/3/2016|      9917|    152.58|    97.44|   1513135.86| 966312.48|   546823.38|
# |                Asia|  Kyrgyzstan|         Snacks|      Offline|             H|11/22/2018|766909492|12/15/2018|      4416|    152.58|    97.44|    673793.28| 430295.04|   243498.24|
# |  Sub-Saharan Africa|  Madagascar|        Clothes|       Online|             C|10/27/2019|935543191|10/29/2019|      6875|    109.28|    35.84|     751300.0|  246400.0|    504900.0|
# |              Europe|     Romania|           Meat|       Online|             M| 1/25/2015|977573192|  2/7/2015|      4486|    421.89|   364.69|   1892598.54|1635999.34|    256599.2|
# |              Europe|       Malta|  Personal Care|      Offline|             H| 5/21/2012|285235822| 6/22/2012|      6473|     81.73|    56.67|    529038.29| 366824.91|   162213.38|
# +--------------------+------------+---------------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Item Type: string (nullable = true)
#  |-- Sales Channel: string (nullable = true)
#  |-- Order Priority: string (nullable = true)
#  |-- Order Date: string (nullable = true)
#  |-- Order ID: integer (nullable = true)
#  |-- Ship Date: string (nullable = true)
#  |-- Units Sold: integer (nullable = true)
#  |-- Unit Price: double (nullable = true)
#  |-- Unit Cost: double (nullable = true)
#  |-- Total Revenue: double (nullable = true)
#  |-- Total Cost: double (nullable = true)
#  |-- Total Profit: double (nullable = true)

# %%
# change the date format
from pyspark.sql.functions import to_date,col

sales = df.withColumn("Ship Date", to_date(col("Ship Date"), "M/d/yyyy")).withColumn("Order Date", to_date(col("Order Date"), "M/d/yyyy"))

# %%
sales.show()
# Out:
# +--------------------+------------+---------------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# |              Region|     Country|      Item Type|Sales Channel|Order Priority|Order Date| Order ID| Ship Date|Units Sold|Unit Price|Unit Cost|Total Revenue|Total Cost|Total Profit|
# +--------------------+------------+---------------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# |Australia and Oce...|       Palau|Office Supplies|       Online|             H|2016-03-06|517073523|2016-03-26|      2401|    651.21|   524.96|   1563555.21|1260428.96|   303126.25|
# |              Europe|      Poland|      Beverages|       Online|             L|2010-04-18|380507028|2010-05-26|      9340|     47.45|    31.79|     443183.0|  296918.6|    146264.4|
# |       North America|      Canada|         Cereal|       Online|             M|2015-01-08|504055583|2015-01-31|       103|     205.7|   117.11|      21187.1|  12062.33|     9124.77|
# |              Europe|     Belarus|         Snacks|       Online|             C|2014-01-19|954955518|2014-02-27|      1414|    152.58|    97.44|    215748.12| 137780.16|    77967.96|
# |Middle East and N...|        Oman|         Cereal|      Offline|             H|2019-04-26|970755660|2019-06-02|      7027|     205.7|   117.11|    1445453.9| 822931.97|   622521.93|
# |  Sub-Saharan Africa|Burkina Faso|Office Supplies|       Online|             C|2012-03-03|309317338|2012-04-05|      2729|    651.21|   524.96|   1777152.09|1432615.84|   344536.25|
# |              Europe|  Montenegro|  Personal Care|       Online|             H|2012-11-24|598814380|2012-12-25|      1337|     81.73|    56.67|    109273.01|  75767.79|    33505.22|
# |Middle East and N...|  Azerbaijan|      Cosmetics|      Offline|             M|2011-03-18|387733113|2011-05-05|      7699|     437.2|   263.33|    3366002.8|2027377.67|  1338625.13|
# |  Sub-Saharan Africa| South Sudan|        Clothes|      Offline|             C|2014-05-10|994872367|2014-06-17|      3696|    109.28|    35.84|    403898.88| 132464.64|   271434.24|
# |       North America|   Greenland|  Personal Care|       Online|             C|2020-05-25|659343469|2020-06-14|      3239|     81.73|    56.67|    264723.47| 183554.13|    81169.34|
# |              Europe|    Portugal|      Cosmetics|       Online|             M|2012-11-12|390570247|2012-11-13|      7270|     437.2|   263.33|    3178444.0| 1914409.1|   1264034.9|
# |  Sub-Saharan Africa|Sierra Leone|        Clothes|      Offline|             C|2019-07-25|818289029|2019-07-27|      8763|    109.28|    35.84|    957620.64| 314065.92|   643554.72|
# |              Europe|     Germany|  Personal Care|      Offline|             H|2010-12-25|842548644|2011-01-24|      7722|     81.73|    56.67|    631119.06| 437605.74|   193513.32|
# |              Europe|  Montenegro|  Personal Care|      Offline|             L|2012-08-03|783710420|2012-08-10|      6184|     81.73|    56.67|    505418.32| 350447.28|   154971.04|
# |                Asia|  Bangladesh|         Cereal|      Offline|             L|2013-12-03|132448184|2014-01-15|      3216|     205.7|   117.11|     661531.2| 376625.76|   284905.44|
# |  Sub-Saharan Africa|  Mauritius |         Snacks|       Online|             M|2016-09-22|699748265|2016-10-03|      9917|    152.58|    97.44|   1513135.86| 966312.48|   546823.38|
# |                Asia|  Kyrgyzstan|         Snacks|      Offline|             H|2018-11-22|766909492|2018-12-15|      4416|    152.58|    97.44|    673793.28| 430295.04|   243498.24|
# |  Sub-Saharan Africa|  Madagascar|        Clothes|       Online|             C|2019-10-27|935543191|2019-10-29|      6875|    109.28|    35.84|     751300.0|  246400.0|    504900.0|
# |              Europe|     Romania|           Meat|       Online|             M|2015-01-25|977573192|2015-02-07|      4486|    421.89|   364.69|   1892598.54|1635999.34|    256599.2|
# |              Europe|       Malta|  Personal Care|      Offline|             H|2012-05-21|285235822|2012-06-22|      6473|     81.73|    56.67|    529038.29| 366824.91|   162213.38|
# +--------------------+------------+---------------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# only showing top 20 rows

# %%
# using pivot
sales.groupby("Region").pivot("Item type").agg(F.sum("Total Revenue")).show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |              Region|           Baby Food|           Beverages|              Cereal|             Clothes|           Cosmetics|              Fruits|           Household|                Meat|     Office Supplies|       Personal Care|              Snacks|          Vegetables|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |Middle East and N...|6.589853417871995...|1.229548072805000...|5.314294756979993E10|2.838726869503998...|1.132455730452004...|     2.41171967715E9|1.731096050655099...|1.093018200237601E11|1.690250661731100...|2.119679752288995E10|3.948516323783993...|3.993084190387990...|
# |Australia and Oce...|4.308397932991994E10| 8.006479925599989E9|3.474618822840001E10|1.839053493311999E10|7.397465315399995E10|1.5751519914000006E9|1.129951974508799...|7.126966000475998E10|1.102115292915000...|1.385019799492997...|2.582016618335998...|2.608697810534002E10|
# |              Europe|1.380352471793598...|2.566939736920002E10|1.112580251431002...|5.906454994959993E10|2.358376636520008E11| 5.043522951600011E9|3.605804213109301E11|2.279944018043994E11|3.521245439228996...|4.409646885511988E10|8.247907934784004E10|8.306036780692012E10|
# |  Sub-Saharan Africa|1.380659726801602...|2.563994045664996E10|    1.11228461322E11|5.902636828255997...|2.366224717536001E11| 5.029833565079993E9|3.609105032533803E11|2.283500846067003E11|3.520228841810101...|4.419086814934003E10|    8.24595761145E10|   8.341485324234E10|
# |Central America a...|5.746721066927994E10|1.068340740545000...|4.638339955259998E10|2.466084320671998E10|9.845160206840009E10|2.1059448627900035E9|1.510620793168999E11|9.512857060392006E10|1.465564847609099...|    1.83372484702E10|3.438879944478004...|3.461112037030003E10|
# |       North America|1.151933640960000...| 2.155028298799999E9| 9.220122572099998E9| 4.884802995680002E9|    1.97646372436E10|4.1773854636000025E8|3.041581453020000...|1.905937351752000...|2.927126889686998...|3.6967785045400043E9| 6.832964659139995E9| 6.902768144780006E9|
# |                Asia|7.766504468248003E10|1.441881612794999...|6.254535140259991...|3.325050320640008E10|1.330279697899999...| 2.843430962129997E9|  2.0326055144948E11|1.281677325066601...|  1.9833887536323E11|2.481343101731999...|4.645520653188014E10|4.687894697952007E10|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+

# %%
# to see highest which region is selling highest units
salesbyregion = sales.groupBy("Region").agg(F.sum("Units Sold").alias("Total Units Sold"))
max_val = salesbyregion.select(F.max('Total Units Sold')).collect()[0][0]
salesbyregion.filter(F.col('Total Units Sold') == max_val).show()
# Out:
# +------------------+----------------+
# |            Region|Total Units Sold|
# +------------------+----------------+
# |Sub-Saharan Africa|      6486855992|
# +------------------+----------------+

# %%
# highest cost of country
costbycountry = sales.groupby("Country").agg(F.sum("Total Cost").alias("Total Cost")) # group country according to totalcost
max_val = costbycountry.select(F.max('Total cost')).collect()[0][0]
costbycountry.filter(F.col('Total cost') == max_val).show()
# Out:
# +-------+--------------------+
# |Country|          Total Cost|
# +-------+--------------------+
# | Rwanda|2.563928572492000...|
# +-------+--------------------+

# %%
sales.groupBy("Region").agg(F.sum("Units Sold").alias("Total Units Sold")).filter(
    F.col('Total Units Sold') == salesbyregion.select(F.max('Total Units Sold')).collect()[0][0]
).show()
# Out:
# +------------------+----------------+
# |            Region|Total Units Sold|
# +------------------+----------------+
# |Sub-Saharan Africa|      6486855992|
# +------------------+----------------+

# %%
salesbyregion.select(F.max('Total Units Sold')).collect()[0][0]
# Out:
# 6486855992

# %%
import pyspark.sql.functions as F
sales2018 = sales.filter(F.year("Order Date") == "2018")

# %%
# filter data of 2020
sales2020 = sales.filter(F.year("Order Date")== "2020")

# %%
import pyspark.sql.functions as F

INBOTH = sales2018.alias('df1').join(sales2020.alias('df2'), F.col("df1.Item Type") == F.col("df2.Item Type"), "inner").select('df1.*')
INBOTH.show()
# Out:
# +------+-------+---------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# |Region|Country|Item Type|Sales Channel|Order Priority|Order Date| Order ID| Ship Date|Units Sold|Unit Price|Unit Cost|Total Revenue|Total Cost|Total Profit|
# +------+-------+---------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# |Europe| Monaco|Baby Food|      Offline|             H|2018-10-29|839051043|2018-10-30|      2704|    255.28|   159.42|    690277.12| 431071.68|   259205.44|
# +------+-------+---------+-------------+--------------+----------+---------+----------+----------+----------+---------+-------------+----------+------------+
# only showing top 20 rows

# %%
sales.groupBy("Region", "Item Type").agg(F.sum(F.col("Total Profit")).alias("Total Profit")).orderBy(F.asc(F.col("Region")), F.desc("Total Profit")).show()
# Out:
# +--------------------+---------------+--------------------+
# |              Region|      Item Type|        Total Profit|
# +--------------------+---------------+--------------------+
# |                Asia|      Cosmetics|5.290387261525008...|
# |                Asia|      Household|5.040832476651991E10|
# |                Asia|Office Supplies|   3.845193257875E10|
# |                Asia|      Baby Food|2.916394227226006E10|
# |                Asia|         Cereal|2.693676558461999...|
# |                Asia|        Clothes|2.234550654720004...|
# |                Asia|     Vegetables|1.920983982096000...|
# |                Asia|           Meat|    1.73770278968E10|
# |                Asia|         Snacks|1.678817727203999...|
# |                Asia|  Personal Care| 7.608278249040002E9|
# |                Asia|      Beverages| 4.758665133059997E9|
# |                Asia|         Fruits| 7.344768080099986E8|
# |Australia and Oce...|      Cosmetics|2.941896830715001E10|
# |Australia and Oce...|      Household|2.802264664512004E10|
# |Australia and Oce...|Office Supplies|    2.13666951875E10|
# |Australia and Oce...|      Baby Food|1.617843253903998...|
# |Australia and Oce...|         Cereal|1.496434037507999...|
# |Australia and Oce...|        Clothes|1.235908570175999...|
# |Australia and Oce...|     Vegetables|1.068980220557001...|
# |Australia and Oce...|           Meat| 9.662766484800001E9|
# +--------------------+---------------+--------------------+
# only showing top 20 rows

# %%
import pyspark.sql.functions as F
# import pandas as pd
# sales.groupby("Country","Region","Item Type").agg(
#     F.sum("Total Profit").alias("Total Profit")
# ).orderBy("Country","Region",F.desc("Total Profit")).toPandas().head(50)



sales.groupby("Country","Region","Item Type").agg(
    F.sum("Total Revenue").alias("Total Revenue")
).orderBy("Country","Region",F.desc("Total Revenue")).show()
# Out:
# +-----------+--------------------+---------------+--------------------+
# |    Country|              Region|      Item Type|       Total Revenue|
# +-----------+--------------------+---------------+--------------------+
# |Afghanistan|Middle East and N...|      Household|     7.48595318903E9|
# |Afghanistan|Middle East and N...|Office Supplies| 7.329326221350002E9|
# |Afghanistan|Middle East and N...|      Cosmetics|4.8975655524000025E9|
# |Afghanistan|Middle East and N...|           Meat| 4.819488259740001E9|
# |Afghanistan|Middle East and N...|      Baby Food|2.8656716785599995E9|
# |Afghanistan|Middle East and N...|         Cereal|      2.3137662592E9|
# |Afghanistan|Middle East and N...|     Vegetables|1.7521981747399995E9|
# |Afghanistan|Middle East and N...|         Snacks|     1.73436450102E9|
# |Afghanistan|Middle East and N...|        Clothes|1.2510146004799998E9|
# |Afghanistan|Middle East and N...|  Personal Care| 9.350629589399999E8|
# |Afghanistan|Middle East and N...|      Beverages|       5.410492893E8|
# |Afghanistan|Middle East and N...|         Fruits|      1.0592626101E8|
# |    Albania|              Europe|Office Supplies| 7.458215658180001E9|
# |    Albania|              Europe|      Household| 7.423412472809996E9|
# |    Albania|              Europe|      Cosmetics|      4.8785696496E9|
# |    Albania|              Europe|           Meat| 4.761551793600001E9|
# |    Albania|              Europe|      Baby Food|2.8543061023999996E9|
# |    Albania|              Europe|         Cereal|      2.3095633968E9|
# |    Albania|              Europe|     Vegetables|     1.74040750076E9|
# |    Albania|              Europe|         Snacks|1.7071434661200004E9|
# +-----------+--------------------+---------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.window import Window
import pyspark.sql.functions as F

window_spec = Window.partitionBy("Country", "Region", "Item Type").orderBy(F.desc("Total Revenue"))
result = sales.withColumn("Total Revenue", F.sum("Total Revenue").over(window_spec))
result = result.withColumn("row_number", F.row_number().over(Window.partitionBy("Country", "Region").orderBy(F.desc("Total Revenue")))) \
               .filter(F.col("row_number") == 1) \
               .drop("row_number")

# Display only the selected columns: "Country", "Region", "Item Type", and "Total Revenue"
result.select("Country", "Region", "Item Type", "Total Revenue") \
      .orderBy("Country", "Region", F.desc("Total Revenue")) \
      .show()
# Out:
# +--------------------+--------------------+---------------+-------------------+
# |             Country|              Region|      Item Type|      Total Revenue|
# +--------------------+--------------------+---------------+-------------------+
# |         Afghanistan|Middle East and N...|      Household|    7.48595318903E9|
# |             Albania|              Europe|Office Supplies|7.458215658179998E9|
# |             Algeria|Middle East and N...|      Household|7.509104734910005E9|
# |             Andorra|              Europe|      Household|7.485526164499994E9|
# |              Angola|  Sub-Saharan Africa|      Household|     7.5525469628E9|
# |Antigua and Barbuda |Central America a...|      Household|7.551797832130007E9|
# |             Armenia|              Europe|      Household|7.575654402859997E9|
# |           Australia|Australia and Oce...|      Household|7.504088700290007E9|
# |             Austria|              Europe|      Household|7.462722119020013E9|
# |          Azerbaijan|Middle East and N...|      Household|7.587695959990002E9|
# |             Bahrain|Middle East and N...|      Household|     7.5119896565E9|
# |          Bangladesh|                Asia|      Household|7.547983346970021E9|
# |            Barbados|Central America a...|      Household|7.594967405859992E9|
# |             Belarus|              Europe|      Household|7.410804222720001E9|
# |             Belgium|              Europe|      Household|7.486871392009994E9|
# |              Belize|Central America a...|      Household|7.563170450990001E9|
# |               Benin|  Sub-Saharan Africa|      Household|7.497468817670002E9|
# |              Bhutan|                Asia|      Household|7.636575900869997E9|
# |Bosnia and Herzeg...|              Europe|      Household|7.603678305309994E9|
# |            Botswana|  Sub-Saharan Africa|      Household|7.504565845069991E9|
# +--------------------+--------------------+---------------+-------------------+
# only showing top 20 rows

# %%
del result

# %%
sales.printSchema()
# Out:
# root
#  |-- Region: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Item Type: string (nullable = true)
#  |-- Sales Channel: string (nullable = true)
#  |-- Order Priority: string (nullable = true)
#  |-- Order Date: date (nullable = true)
#  |-- Order ID: integer (nullable = true)
#  |-- Ship Date: date (nullable = true)
#  |-- Units Sold: integer (nullable = true)
#  |-- Unit Price: double (nullable = true)
#  |-- Unit Cost: double (nullable = true)
#  |-- Total Revenue: double (nullable = true)
#  |-- Total Cost: double (nullable = true)
#  |-- Total Profit: double (nullable = true)

# %%
#selected columns as per requirements
columns = ["Region","Item Type","Total Profit"]
filterdata = sales.select(*columns)

# %%
filterdata.show()
filterdata.printSchema()
# Out:
# +--------------------+---------------+------------+
# |              Region|      Item Type|Total Profit|
# +--------------------+---------------+------------+
# |Australia and Oce...|Office Supplies|   303126.25|
# |              Europe|      Beverages|    146264.4|
# |       North America|         Cereal|     9124.77|
# |              Europe|         Snacks|    77967.96|
# |Middle East and N...|         Cereal|   622521.93|
# |  Sub-Saharan Africa|Office Supplies|   344536.25|
# |              Europe|  Personal Care|    33505.22|
# |Middle East and N...|      Cosmetics|  1338625.13|
# |  Sub-Saharan Africa|        Clothes|   271434.24|
# |       North America|  Personal Care|    81169.34|
# |              Europe|      Cosmetics|   1264034.9|
# |  Sub-Saharan Africa|        Clothes|   643554.72|
# |              Europe|  Personal Care|   193513.32|
# |              Europe|  Personal Care|   154971.04|
# |                Asia|         Cereal|   284905.44|
# |  Sub-Saharan Africa|         Snacks|   546823.38|
# |                Asia|         Snacks|   243498.24|
# |  Sub-Saharan Africa|        Clothes|    504900.0|
# |              Europe|           Meat|    256599.2|
# |              Europe|  Personal Care|   162213.38|
# +--------------------+---------------+------------+
# only showing top 20 rows
#
# root
#  |-- Region: string (nullable = true)
#  |-- Item Type: string (nullable = true)
#  |-- Total Profit: double (nullable = true)

# %%
# result of first requriments
import pyspark.sql.functions as F

filterdata.groupBy("Region", "Item Type").agg(
    F.sum("Total Profit").alias("Total Profit")
  ).orderBy(
      "Region",F.desc("Total Profit")
  ).show()
# Out:
# +--------------------+---------------+--------------------+
# |              Region|      Item Type|        Total Profit|
# +--------------------+---------------+--------------------+
# |                Asia|      Cosmetics|5.290387261525008...|
# |                Asia|      Household|5.040832476651991E10|
# |                Asia|Office Supplies|   3.845193257875E10|
# |                Asia|      Baby Food|2.916394227226006E10|
# |                Asia|         Cereal|2.693676558461999...|
# |                Asia|        Clothes|2.234550654720004...|
# |                Asia|     Vegetables|1.920983982096000...|
# |                Asia|           Meat|    1.73770278968E10|
# |                Asia|         Snacks|1.678817727203999...|
# |                Asia|  Personal Care| 7.608278249040002E9|
# |                Asia|      Beverages| 4.758665133059997E9|
# |                Asia|         Fruits| 7.344768080099986E8|
# |Australia and Oce...|      Cosmetics|2.941896830715001E10|
# |Australia and Oce...|      Household|2.802264664512004E10|
# |Australia and Oce...|Office Supplies|    2.13666951875E10|
# |Australia and Oce...|      Baby Food|1.617843253903998...|
# |Australia and Oce...|         Cereal|1.496434037507999...|
# |Australia and Oce...|        Clothes|1.235908570175999...|
# |Australia and Oce...|     Vegetables|1.068980220557001...|
# |Australia and Oce...|           Meat| 9.662766484800001E9|
# +--------------------+---------------+--------------------+
# only showing top 20 rows

# %%
result1 = filterdata.groupBy("Region", "Item Type") \
           .agg(sum("Total Profit").alias("Total Profit")) \
           .orderBy("Region", desc("Total Profit"))
result1.show()
# Out:
# +--------------------+---------------+--------------------+
# |              Region|      Item Type|        Total Profit|
# +--------------------+---------------+--------------------+
# |                Asia|      Cosmetics|5.290387261525008...|
# |                Asia|      Household|5.040832476651991E10|
# |                Asia|Office Supplies|   3.845193257875E10|
# |                Asia|      Baby Food|2.916394227226006E10|
# |                Asia|         Cereal|2.693676558461999...|
# |                Asia|        Clothes|2.234550654720004...|
# |                Asia|     Vegetables|1.920983982096000...|
# |                Asia|           Meat|    1.73770278968E10|
# |                Asia|         Snacks|1.678817727203999...|
# |                Asia|  Personal Care| 7.608278249040002E9|
# |                Asia|      Beverages| 4.758665133059997E9|
# |                Asia|         Fruits| 7.344768080099986E8|
# |Australia and Oce...|      Cosmetics|2.941896830715001E10|
# |Australia and Oce...|      Household|2.802264664512004E10|
# |Australia and Oce...|Office Supplies|    2.13666951875E10|
# |Australia and Oce...|      Baby Food|1.617843253903998...|
# |Australia and Oce...|         Cereal|1.496434037507999...|
# |Australia and Oce...|        Clothes|1.235908570175999...|
# |Australia and Oce...|     Vegetables|1.068980220557001...|
# |Australia and Oce...|           Meat| 9.662766484800001E9|
# +--------------------+---------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.types import DecimalType
decimal_type = DecimalType(20, 2)

result1.withColumn("Total Profit" , col("Total Profit").cast(decimal_type)).show()
# Out:
# +--------------------+---------------+--------------+
# |              Region|      Item Type|  Total Profit|
# +--------------------+---------------+--------------+
# |                Asia|      Cosmetics|52903872615.25|
# |                Asia|      Household|50408324766.52|
# |                Asia|Office Supplies|38451932578.75|
# |                Asia|      Baby Food|29163942272.26|
# |                Asia|         Cereal|26936765584.62|
# |                Asia|        Clothes|22345506547.20|
# |                Asia|     Vegetables|19209839820.96|
# |                Asia|           Meat|17377027896.80|
# |                Asia|         Snacks|16788177272.04|
# |                Asia|  Personal Care| 7608278249.04|
# |                Asia|      Beverages| 4758665133.06|
# |                Asia|         Fruits|  734476808.01|
# |Australia and Oce...|      Cosmetics|29418968307.15|
# |Australia and Oce...|      Household|28022646645.12|
# |Australia and Oce...|Office Supplies|21366695187.50|
# |Australia and Oce...|      Baby Food|16178432539.04|
# |Australia and Oce...|         Cereal|14964340375.08|
# |Australia and Oce...|        Clothes|12359085701.76|
# |Australia and Oce...|     Vegetables|10689802205.57|
# |Australia and Oce...|           Meat| 9662766484.80|
# +--------------------+---------------+--------------+
# only showing top 20 rows

# %%
# filterdata.groupBy("Region","Item Type").agg(F.sum("Total Profit").alias("Total Profit")).orderBy("Region","Item Type").show()
saleregion = filterdata.groupBy("Region","Item Type").agg(F.sum("Total Profit").alias("Total Profit")).orderBy("Region","Item Type")
saleregion.show(100)
# Out:
# +--------------------+---------------+--------------------+
# |              Region|      Item Type|        Total Profit|
# +--------------------+---------------+--------------------+
# |                Asia|      Baby Food|2.916394227226006E10|
# |                Asia|      Beverages| 4.758665133059997E9|
# |                Asia|         Cereal|2.693676558461999...|
# |                Asia|        Clothes|2.234550654720004...|
# |                Asia|      Cosmetics|5.290387261525008...|
# |                Asia|         Fruits| 7.344768080099986E8|
# |                Asia|      Household|5.040832476651991E10|
# |                Asia|           Meat|    1.73770278968E10|
# |                Asia|Office Supplies|   3.845193257875E10|
# |                Asia|  Personal Care| 7.608278249040002E9|
# |                Asia|         Snacks|1.678817727203999...|
# |                Asia|     Vegetables|1.920983982096000...|
# |Australia and Oce...|      Baby Food|1.617843253903998...|
# |Australia and Oce...|      Beverages| 2.642391478080001E9|
# |Australia and Oce...|         Cereal|1.496434037507999...|
# |Australia and Oce...|        Clothes|1.235908570175999...|
# |Australia and Oce...|      Cosmetics|2.941896830715001E10|
# |Australia and Oce...|         Fruits| 4.068720577999997E8|
# |Australia and Oce...|      Household|2.802264664512004E10|
# |Australia and Oce...|           Meat| 9.662766484800001E9|
# |Australia and Oce...|Office Supplies|    2.13666951875E10|
# |Australia and Oce...|  Personal Care| 4.246738795460012E9|
# |Australia and Oce...|         Snacks| 9.330999890879995E9|
# |Australia and Oce...|     Vegetables|1.068980220557001...|
# |Central America a...|      Baby Food|2.157946887635999...|
# |Central America a...|      Beverages|3.5258621700600085E9|
# |Central America a...|         Cereal|1.997620498961994E10|
# |Central America a...|        Clothes|1.657295319456000...|
# |Central America a...|      Cosmetics|3.915320231388998...|
# |Central America a...|         Fruits|      5.4397932683E8|
# |Central America a...|      Household|3.746317866310004E10|
# |Central America a...|           Meat|1.289756628159997...|
# |Central America a...|Office Supplies|   2.841288708875E10|
# |Central America a...|  Personal Care| 5.622555324400005E9|
# |Central America a...|         Snacks|1.242756849774000...|
# |Central America a...|     Vegetables|1.418278611565001E10|
# |              Europe|      Baby Food| 5.18335114173202E10|
# |              Europe|      Beverages| 8.471712598560016E9|
# |              Europe|         Cereal|4.791613246196998...|
# |              Europe|        Clothes|3.969345304079996E10|
# |              Europe|      Cosmetics|9.379024377669989E10|
# |              Europe|         Fruits|1.3027749531999998E9|
# |              Europe|      Household|8.942342649506995E10|
# |              Europe|           Meat|3.091156411200006E10|
# |              Europe|Office Supplies|    6.82663406125E10|
# |              Europe|  Personal Care|1.352083090064001...|
# |              Europe|         Snacks|2.980663543871999...|
# |              Europe|     Vegetables|3.403609645366002E10|
# |Middle East and N...|      Baby Food|2.474550879964000...|
# |Middle East and N...|      Beverages|4.0578973277400084E9|
# |Middle East and N...|         Cereal|2.288737834326002...|
# |Middle East and N...|        Clothes|1.907724206591997E10|
# |Middle East and N...|      Cosmetics|4.503661433067005E10|
# |Middle East and N...|         Fruits|      6.2296296055E8|
# |Middle East and N...|      Household|4.293093337649009E10|
# |Middle East and N...|           Meat|    1.48191806048E10|
# |Middle East and N...|Office Supplies|   3.276886811375E10|
# |Middle East and N...|  Personal Care| 6.499348414580006E9|
# |Middle East and N...|         Snacks|1.426931380871997E10|
# |Middle East and N...|     Vegetables|1.636267719973996E10|
# |       North America|      Baby Food| 4.325617315199999E9|
# |       North America|      Beverages| 7.112274638400004E8|
# |       North America|         Cereal|3.9708831242700033E9|
# |       North America|        Clothes|3.2827592606400027E9|
# |       North America|      Cosmetics| 7.860195511309997E9|
# |       North America|         Fruits|1.0790459771999994E8|
# |       North America|      Household|7.5430783097999935E9|
# |       North America|           Meat|      2.5840768096E9|
# |       North America|Office Supplies|     5.67481718375E9|
# |       North America|  Personal Care|1.1335038458799994E9|
# |       North America|         Snacks|2.4693254116199985E9|
# |       North America|     Vegetables|     2.82858466169E9|
# |  Sub-Saharan Africa|      Baby Food|5.184504912691994E10|
# |  Sub-Saharan Africa|      Beverages| 8.461990886219993E9|
# |  Sub-Saharan Africa|         Cereal|4.790340004140001E10|
# |  Sub-Saharan Africa|        Clothes| 3.96677936188801E10|
# |  Sub-Saharan Africa|      Cosmetics|9.410235398855992E10|
# |  Sub-Saharan Africa|         Fruits|1.2992388951600006E9|
# |  Sub-Saharan Africa|      Household|8.950528634261993E10|
# |  Sub-Saharan Africa|           Meat|3.095978771599992...|
# |  Sub-Saharan Africa|Office Supplies|   6.824663185125E10|
# |  Sub-Saharan Africa|  Personal Care|1.354977555148000...|
# |  Sub-Saharan Africa|         Snacks|2.979958727850006E10|
# |  Sub-Saharan Africa|     Vegetables|3.418135586906997...|
# +--------------------+---------------+--------------------+

# %%
from pyspark.sql.types import DecimalType
decimal_type = DecimalType(20, 2)

saleregion.withColumn("Total Profit", col("Total Profit").cast(decimal_type)).show()
# Out:
# +--------------------+---------------+--------------+
# |              Region|      Item Type|  Total Profit|
# +--------------------+---------------+--------------+
# |                Asia|      Baby Food|29163942272.26|
# |                Asia|      Beverages| 4758665133.06|
# |                Asia|         Cereal|26936765584.62|
# |                Asia|        Clothes|22345506547.20|
# |                Asia|      Cosmetics|52903872615.25|
# |                Asia|         Fruits|  734476808.01|
# |                Asia|      Household|50408324766.52|
# |                Asia|           Meat|17377027896.80|
# |                Asia|Office Supplies|38451932578.75|
# |                Asia|  Personal Care| 7608278249.04|
# |                Asia|         Snacks|16788177272.04|
# |                Asia|     Vegetables|19209839820.96|
# |Australia and Oce...|      Baby Food|16178432539.04|
# |Australia and Oce...|      Beverages| 2642391478.08|
# |Australia and Oce...|         Cereal|14964340375.08|
# |Australia and Oce...|        Clothes|12359085701.76|
# |Australia and Oce...|      Cosmetics|29418968307.15|
# |Australia and Oce...|         Fruits|  406872057.80|
# |Australia and Oce...|      Household|28022646645.12|
# |Australia and Oce...|           Meat| 9662766484.80|
# +--------------------+---------------+--------------+
# only showing top 20 rows
